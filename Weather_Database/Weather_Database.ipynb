# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 749

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | adrar
# Processing Record 2 of the Set 1 | kaitangata
# Processing Record 3 of the Set 1 | gizo
# Processing Record 4 of the Set 1 | sakakah
# Processing Record 5 of the Set 1 | parfenyevo
# Processing Record 6 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of the Set 1 | rikitea
# Processing Record 8 of the Set 1 | puerto carreno
# Processing Record 9 of the Set 1 | termiz
# Processing Record 10 of the Set 1 | yellowknife
# Processing Record 11 of the Set 1 | vaini
# Processing Record 12 of the Set 1 | nanortalik
# Processing Record 13 of the Set 1 | kysyl-syr
# Processing Record 14 of the Set 1 | mataura
# Processing Record 15 of the Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of the Set 1 | punta arenas
# Processing Record 17 of the Set 1 | botwood
# Processing Record 18 of the Set 1 | hamilton
# Processing Record 19 of the Set 1 | mandalgovi
# Processing Record 20 of the Set 1 | east london
# Processing Record 21 of the Set 1 | machiques
# Processing Record 22 of the Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of the Set 1 | qaanaaq
# Processing Record 24 of the Set 1 | busselton
# Processing Record 25 of the Set 1 | abu zabad
# Processing Record 26 of the Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of the Set 1 | dalbandin
# Processing Record 28 of the Set 1 | ancud
# Processing Record 29 of the Set 1 | vysokogornyy
# Processing Record 30 of the Set 1 | puerto ayora
# Processing Record 31 of the Set 1 | avarua
# Processing Record 32 of the Set 1 | severo-kurilsk
# Processing Record 33 of the Set 1 | nikolskoye
# Processing Record 34 of the Set 1 | nguiu
# Processing Record 35 of the Set 1 | mayo
# Processing Record 36 of the Set 1 | mys shmidta
# Processing Record 37 of the Set 1 | coihaique
# Processing Record 38 of the Set 1 | cabo san lucas
# Processing Record 39 of the Set 1 | takoradi
# Processing Record 40 of the Set 1 | bandar-e anzali
# Processing Record 41 of the Set 1 | butaritari
# Processing Record 42 of the Set 1 | albany
# Processing Record 43 of the Set 1 | leavenworth
# Processing Record 44 of the Set 1 | castro
# Processing Record 45 of the Set 1 | codrington
# Processing Record 46 of the Set 1 | hermanus
# Processing Record 47 of the Set 1 | flinders
# Processing Record 48 of the Set 1 | provideniya
# Processing Record 49 of the Set 1 | port alfred
# Processing Record 50 of the Set 1 | torbay
# Processing Record 1 of the Set 2 | arraial do cabo
# Processing Record 2 of the Set 2 | ilulissat
# Processing Record 3 of the Set 2 | hilo
# Processing Record 4 of the Set 2 | kerouane
# Processing Record 5 of the Set 2 | urengoy
# Processing Record 6 of the Set 2 | ushuaia
# Processing Record 7 of the Set 2 | hobart
# Processing Record 8 of the Set 2 | atuona
# Processing Record 9 of the Set 2 | jamestown
# Processing Record 10 of the Set 2 | tasiilaq
# Processing Record 11 of the Set 2 | new norfolk
# Processing Record 12 of the Set 2 | bluff
# Processing Record 13 of the Set 2 | pacific grove
# Processing Record 14 of the Set 2 | kaberamaido
# Processing Record 15 of the Set 2 | bredasdorp
# Processing Record 16 of the Set 2 | kenai
# Processing Record 17 of the Set 2 | axim
# Processing Record 18 of the Set 2 | povenets
# Processing Record 19 of the Set 2 | ovsyanka
# Processing Record 20 of the Set 2 | pevek
# Processing Record 21 of the Set 2 | sinjai
# Processing Record 22 of the Set 2 | port lincoln
# Processing Record 23 of the Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of the Set 2 | kruisfontein
# Processing Record 25 of the Set 2 | constitucion
# Processing Record 26 of the Set 2 | katsuura
# Processing Record 27 of the Set 2 | aden
# Processing Record 28 of the Set 2 | tiksi
# Processing Record 29 of the Set 2 | victoria
# Processing Record 30 of the Set 2 | georgetown
# Processing Record 31 of the Set 2 | itarema
# Processing Record 32 of the Set 2 | burns lake
# Processing Record 33 of the Set 2 | opoczno
# Processing Record 34 of the Set 2 | zemio
# Processing Record 35 of the Set 2 | saskylakh
# Processing Record 36 of the Set 2 | saint george
# Processing Record 37 of the Set 2 | pisco
# City not found. Skipping...
# Processing Record 38 of the Set 2 | bardiyah
# Processing Record 39 of the Set 2 | mount isa
# Processing Record 40 of the Set 2 | flin flon
# Processing Record 41 of the Set 2 | la ronge
# Processing Record 42 of the Set 2 | dikson
# Processing Record 43 of the Set 2 | amapa
# Processing Record 44 of the Set 2 | sept-iles
# Processing Record 45 of the Set 2 | toliary
# City not found. Skipping...
# Processing Record 46 of the Set 2 | krivosheino
# Processing Record 47 of the Set 2 | karauzyak
# Processing Record 48 of the Set 2 | sitka
# Processing Record 49 of the Set 2 | camacha
# Processing Record 50 of the Set 2 | cape town
# Processing Record 1 of the Set 3 | chikitigarh
# Processing Record 2 of the Set 3 | saint-pierre
# Processing Record 3 of the Set 3 | belushya guba
# Processing Record 4 of the Set 3 | saint-philippe
# Processing Record 5 of the Set 3 | qaqortoq
# Processing Record 6 of the Set 3 | faanui
# Processing Record 7 of the Set 3 | rawson
# Processing Record 8 of the Set 3 | buraydah
# Processing Record 9 of the Set 3 | chokurdakh
# Processing Record 10 of the Set 3 | sentyabrskiy
# Processing Record 11 of the Set 3 | tuktoyaktuk
# Processing Record 12 of the Set 3 | luderitz
# Processing Record 13 of the Set 3 | havre-saint-pierre
# Processing Record 14 of the Set 3 | coahuayana
# Processing Record 15 of the Set 3 | kapaa
# Processing Record 16 of the Set 3 | nome
# Processing Record 17 of the Set 3 | gazojak
# Processing Record 18 of the Set 3 | victor harbor
# Processing Record 19 of the Set 3 | jalu
# Processing Record 20 of the Set 3 | luganville
# Processing Record 21 of the Set 3 | la sarre
# Processing Record 22 of the Set 3 | ust-ilimsk
# Processing Record 23 of the Set 3 | larsnes
# Processing Record 24 of the Set 3 | tabiauea
# Processing Record 25 of the Set 3 | lekoni
# Processing Record 26 of the Set 3 | barrow
# Processing Record 27 of the Set 3 | skibbereen
# Processing Record 28 of the Set 3 | rexburg
# Processing Record 29 of the Set 3 | mehamn
# Processing Record 30 of the Set 3 | paamiut
# Processing Record 31 of the Set 3 | barentu
# Processing Record 32 of the Set 3 | huarmey
# City not found. Skipping...
# Processing Record 33 of the Set 3 | san juan
# Processing Record 34 of the Set 3 | caravelas
# Processing Record 35 of the Set 3 | virginia beach
# Processing Record 36 of the Set 3 | kodiak
# Processing Record 37 of the Set 3 | christchurch
# Processing Record 38 of the Set 3 | illoqqortoormiut
# Processing Record 39 of the Set 3 | sioux lookout
# Processing Record 40 of the Set 3 | narsaq
# Processing Record 41 of the Set 3 | garden city
# Processing Record 42 of the Set 3 | sharjah
# Processing Record 43 of the Set 3 | mahebourg
# Processing Record 44 of the Set 3 | fairbanks
# Processing Record 45 of the Set 3 | mogok
# Processing Record 46 of the Set 3 | harper
# Processing Record 47 of the Set 3 | port macquarie
# Processing Record 48 of the Set 3 | thompson
# Processing Record 49 of the Set 3 | khonuu
# Processing Record 50 of the Set 3 | rio cuarto
# Processing Record 1 of the Set 4 | rio grande
# Processing Record 2 of the Set 4 | inuvik
# Processing Record 3 of the Set 4 | kashi
# Processing Record 4 of the Set 4 | tiarei
# Processing Record 5 of the Set 4 | sigli
# Processing Record 6 of the Set 4 | hasaki
# Processing Record 7 of the Set 4 | maryville
# Processing Record 8 of the Set 4 | bilibino
# Processing Record 9 of the Set 4 | auki
# Processing Record 10 of the Set 4 | cidreira
# Processing Record 11 of the Set 4 | goderich
# Processing Record 12 of the Set 4 | ayagoz
# Processing Record 13 of the Set 4 | bandarbeyla
# Processing Record 14 of the Set 4 | hithadhoo
# Processing Record 15 of the Set 4 | shevchenkove
# Processing Record 16 of the Set 4 | nkhotakota
# Processing Record 17 of the Set 4 | dourbali
# Processing Record 18 of the Set 4 | guerrero negro
# Processing Record 19 of the Set 4 | kahului
# Processing Record 20 of the Set 4 | nisia floresta
# Processing Record 21 of the Set 4 | saint-augustin
# Processing Record 22 of the Set 4 | greensburg
# Processing Record 23 of the Set 4 | cherskiy
# Processing Record 24 of the Set 4 | aleksandrov gay
# Processing Record 25 of the Set 4 | portland
# Processing Record 26 of the Set 4 | porto santo
# Processing Record 27 of the Set 4 | mecca
# Processing Record 28 of the Set 4 | nador
# Processing Record 29 of the Set 4 | marawi
# Processing Record 30 of the Set 4 | kavaratti
# Processing Record 31 of the Set 4 | sorvag
# City not found. Skipping...
# Processing Record 32 of the Set 4 | fort morgan
# Processing Record 33 of the Set 4 | ocean city
# Processing Record 34 of the Set 4 | fort-shevchenko
# Processing Record 35 of the Set 4 | marv dasht
# Processing Record 36 of the Set 4 | mentok
# Processing Record 37 of the Set 4 | tselinnoye
# Processing Record 38 of the Set 4 | meyungs
# City not found. Skipping...
# Processing Record 39 of the Set 4 | yola
# Processing Record 40 of the Set 4 | lebu
# Processing Record 41 of the Set 4 | bengkulu
# Processing Record 42 of the Set 4 | swift current
# Processing Record 43 of the Set 4 | zhezkazgan
# Processing Record 44 of the Set 4 | shimoda
# Processing Record 45 of the Set 4 | umzimvubu
# Processing Record 46 of the Set 4 | imeni poliny osipenko
# Processing Record 47 of the Set 4 | atar
# Processing Record 48 of the Set 4 | kawalu
# Processing Record 49 of the Set 4 | kutum
# Processing Record 50 of the Set 4 | geraldton
# Processing Record 1 of the Set 5 | suntar
# Processing Record 2 of the Set 5 | sao felix do xingu
# Processing Record 3 of the Set 5 | sorland
# Processing Record 4 of the Set 5 | amderma
# Processing Record 5 of the Set 5 | paradwip
# Processing Record 6 of the Set 5 | boa vista
# Processing Record 7 of the Set 5 | gurupi
# Processing Record 8 of the Set 5 | inhambane
# Processing Record 9 of the Set 5 | alekseyevskaya
# Processing Record 10 of the Set 5 | porechye-rybnoye
# Processing Record 11 of the Set 5 | olga
# Processing Record 12 of the Set 5 | maumere
# Processing Record 13 of the Set 5 | port elizabeth
# Processing Record 14 of the Set 5 | sisophon
# Processing Record 15 of the Set 5 | ternate
# Processing Record 16 of the Set 5 | georgetown
# Processing Record 17 of the Set 5 | marsa matruh
# Processing Record 18 of the Set 5 | coquimbo
# Processing Record 19 of the Set 5 | maple creek
# Processing Record 20 of the Set 5 | kadiri
# Processing Record 21 of the Set 5 | hami
# Processing Record 22 of the Set 5 | usinsk
# Processing Record 23 of the Set 5 | kushmurun
# Processing Record 24 of the Set 5 | turayf
# Processing Record 25 of the Set 5 | savonlinna
# Processing Record 26 of the Set 5 | vestmannaeyjar
# Processing Record 27 of the Set 5 | grand river south east
# Processing Record 28 of the Set 5 | khani
# Processing Record 29 of the Set 5 | manbij
# Processing Record 30 of the Set 5 | clyde river
# Processing Record 31 of the Set 5 | borama
# Processing Record 32 of the Set 5 | nelson bay
# Processing Record 33 of the Set 5 | talnakh
# Processing Record 34 of the Set 5 | airai
# City not found. Skipping...
# Processing Record 35 of the Set 5 | mayor pablo lagerenza
# Processing Record 36 of the Set 5 | port-gentil
# Processing Record 37 of the Set 5 | batabano
# Processing Record 38 of the Set 5 | chico
# Processing Record 39 of the Set 5 | ngukurr
# Processing Record 40 of the Set 5 | nemuro
# Processing Record 41 of the Set 5 | namatanai
# Processing Record 42 of the Set 5 | asosa
# Processing Record 43 of the Set 5 | port augusta
# Processing Record 44 of the Set 5 | avera
# Processing Record 45 of the Set 5 | moanda
# Processing Record 46 of the Set 5 | flagstaff
# Processing Record 47 of the Set 5 | acopiara
# Processing Record 48 of the Set 5 | aripuana
# Processing Record 49 of the Set 5 | elko
# Processing Record 50 of the Set 5 | puqi
# Processing Record 1 of the Set 6 | petatlan
# Processing Record 2 of the Set 6 | gravelbourg
# Processing Record 3 of the Set 6 | yangjiang
# Processing Record 4 of the Set 6 | isangel
# Processing Record 5 of the Set 6 | zheleznogorsk
# Processing Record 6 of the Set 6 | bandundu
# Processing Record 7 of the Set 6 | yenotayevka
# Processing Record 8 of the Set 6 | norman wells
# Processing Record 9 of the Set 6 | bethel
# Processing Record 10 of the Set 6 | mukhen
# Processing Record 11 of the Set 6 | hurghada
# Processing Record 12 of the Set 6 | galiwinku
# Processing Record 13 of the Set 6 | lorengau
# Processing Record 14 of the Set 6 | carupano
# Processing Record 15 of the Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 16 of the Set 6 | nizhneyansk
# Processing Record 17 of the Set 6 | mocuba
# Processing Record 18 of the Set 6 | bahar
# Processing Record 19 of the Set 6 | bubaque
# Processing Record 20 of the Set 6 | skjervoy
# Processing Record 21 of the Set 6 | tumannyy
# Processing Record 22 of the Set 6 | lincoln
# Processing Record 23 of the Set 6 | vilya
# Processing Record 24 of the Set 6 | dhidhdhoo
# Processing Record 25 of the Set 6 | viseu
# Processing Record 26 of the Set 6 | kontagora
# Processing Record 27 of the Set 6 | attawapiskat
# Processing Record 28 of the Set 6 | fereydun kenar
# Processing Record 29 of the Set 6 | teluk nibung
# Processing Record 30 of the Set 6 | shumskiy
# Processing Record 31 of the Set 6 | kjollefjord
# Processing Record 32 of the Set 6 | folldal
# Processing Record 33 of the Set 6 | bage
# Processing Record 34 of the Set 6 | tuatapere
# Processing Record 35 of the Set 6 | zhigansk
# Processing Record 36 of the Set 6 | yablonovo
# Processing Record 37 of the Set 6 | kabo
# Processing Record 38 of the Set 6 | naze
# Processing Record 39 of the Set 6 | iqaluit
# Processing Record 40 of the Set 6 | riviere-au-renard
# Processing Record 41 of the Set 6 | safaga
# Processing Record 42 of the Set 6 | mogadishu
# Processing Record 43 of the Set 6 | rujiena
# Processing Record 44 of the Set 6 | vila franca do campo
# Processing Record 45 of the Set 6 | marsabit
# Processing Record 46 of the Set 6 | dauphin
# Processing Record 47 of the Set 6 | agaro
# Processing Record 48 of the Set 6 | george
# Processing Record 49 of the Set 6 | yulara
# Processing Record 50 of the Set 6 | nakhon thai
# Processing Record 1 of the Set 7 | segezha
# Processing Record 2 of the Set 7 | sabha
# Processing Record 3 of the Set 7 | lompoc
# Processing Record 4 of the Set 7 | voznesenye
# Processing Record 5 of the Set 7 | upernavik
# Processing Record 6 of the Set 7 | muzhi
# Processing Record 7 of the Set 7 | ponta do sol
# Processing Record 8 of the Set 7 | rio gallegos
# Processing Record 9 of the Set 7 | piacabucu
# Processing Record 10 of the Set 7 | patrocinio
# Processing Record 11 of the Set 7 | bambous virieux
# Processing Record 12 of the Set 7 | iralaya
# Processing Record 13 of the Set 7 | arlit
# Processing Record 14 of the Set 7 | pitimbu
# Processing Record 15 of the Set 7 | husavik
# Processing Record 16 of the Set 7 | ambilobe
# Processing Record 17 of the Set 7 | lagoa
# Processing Record 18 of the Set 7 | atbasar
# Processing Record 19 of the Set 7 | sungaipenuh
# Processing Record 20 of the Set 7 | deputatskiy
# Processing Record 21 of the Set 7 | esperance
# Processing Record 22 of the Set 7 | mar del plata
# Processing Record 23 of the Set 7 | fiche
# Processing Record 24 of the Set 7 | teguise
# Processing Record 25 of the Set 7 | douglas
# Processing Record 26 of the Set 7 | vallenar
# Processing Record 27 of the Set 7 | kavarna
# Processing Record 28 of the Set 7 | paoua
# Processing Record 29 of the Set 7 | kozmodemyansk
# Processing Record 30 of the Set 7 | souillac
# Processing Record 31 of the Set 7 | lerwick
# Processing Record 32 of the Set 7 | aitape
# Processing Record 33 of the Set 7 | samarai
# Processing Record 34 of the Set 7 | rocha
# Processing Record 35 of the Set 7 | chuy
# Processing Record 36 of the Set 7 | domoni
# Processing Record 37 of the Set 7 | aksu
# Processing Record 38 of the Set 7 | uray
# Processing Record 39 of the Set 7 | carnarvon
# Processing Record 40 of the Set 7 | lom sak
# Processing Record 41 of the Set 7 | cuajinicuilapa
# Processing Record 42 of the Set 7 | talcahuano
# Processing Record 43 of the Set 7 | sovetskiy
# Processing Record 44 of the Set 7 | chakrata
# Processing Record 45 of the Set 7 | malkerns
# Processing Record 46 of the Set 7 | saint-jerome
# Processing Record 47 of the Set 7 | bundaberg
# Processing Record 48 of the Set 7 | half moon bay
# Processing Record 49 of the Set 7 | itoman
# Processing Record 50 of the Set 7 | kalino
# Processing Record 1 of the Set 8 | ruatoria
# Processing Record 2 of the Set 8 | dicabisagan
# Processing Record 3 of the Set 8 | maues
# Processing Record 4 of the Set 8 | qasigiannguit
# Processing Record 5 of the Set 8 | svetlogorsk
# Processing Record 6 of the Set 8 | kroya
# Processing Record 7 of the Set 8 | okhotsk
# Processing Record 8 of the Set 8 | pemberton
# Processing Record 9 of the Set 8 | eyl
# Processing Record 10 of the Set 8 | guadalupe y calvo
# Processing Record 11 of the Set 8 | zilupe
# Processing Record 12 of the Set 8 | shuyskoye
# Processing Record 13 of the Set 8 | gotsu
# Processing Record 14 of the Set 8 | longonjo
# Processing Record 15 of the Set 8 | carndonagh
# Processing Record 16 of the Set 8 | balkanabat
# Processing Record 17 of the Set 8 | concarneau
# Processing Record 18 of the Set 8 | wahran
# Processing Record 19 of the Set 8 | kholtoson
# Processing Record 20 of the Set 8 | dunedin
# Processing Record 21 of the Set 8 | sao joao da barra
# Processing Record 22 of the Set 8 | canals
# Processing Record 23 of the Set 8 | maine-soroa
# Processing Record 24 of the Set 8 | tiruvottiyur
# Processing Record 25 of the Set 8 | palmer
# Processing Record 26 of the Set 8 | crowley
# Processing Record 27 of the Set 8 | lyaskelya
# Processing Record 28 of the Set 8 | uzumlu
# City not found. Skipping...
# Processing Record 29 of the Set 8 | urgut
# Processing Record 30 of the Set 8 | baykit
# Processing Record 31 of the Set 8 | altay
# Processing Record 32 of the Set 8 | vangaindrano
# Processing Record 33 of the Set 8 | adur
# Processing Record 34 of the Set 8 | verkhnevilyuysk
# Processing Record 35 of the Set 8 | kasangulu
# Processing Record 36 of the Set 8 | owando
# Processing Record 37 of the Set 8 | champerico
# Processing Record 38 of the Set 8 | sohag
# Processing Record 39 of the Set 8 | moshupa
# Processing Record 40 of the Set 8 | levelland
# Processing Record 41 of the Set 8 | tarancon
# Processing Record 42 of the Set 8 | uppsala
# Processing Record 43 of the Set 8 | ararat
# Processing Record 44 of the Set 8 | jacksonville
# Processing Record 45 of the Set 8 | phrai bung
# Processing Record 46 of the Set 8 | ridgecrest
# Processing Record 47 of the Set 8 | poum
# Processing Record 48 of the Set 8 | palabuhanratu
# Processing Record 49 of the Set 8 | khatanga
# Processing Record 50 of the Set 8 | chernyshevskiy
# Processing Record 1 of the Set 9 | inirida
# Processing Record 2 of the Set 9 | chapais
# Processing Record 3 of the Set 9 | molo
# Processing Record 4 of the Set 9 | petropavlovsk-kamchatskiy
# Processing Record 5 of the Set 9 | khash
# Processing Record 6 of the Set 9 | dolores
# Processing Record 7 of the Set 9 | sao filipe
# Processing Record 8 of the Set 9 | suoyarvi
# Processing Record 9 of the Set 9 | bargal
# Processing Record 10 of the Set 9 | makakilo city
# Processing Record 11 of the Set 9 | yerbogachen
# Processing Record 12 of the Set 9 | nouadhibou
# Processing Record 13 of the Set 9 | hofn
# Processing Record 14 of the Set 9 | barbar
# Processing Record 15 of the Set 9 | santa cruz de tenerife
# Processing Record 16 of the Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 17 of the Set 9 | bintulu
# City not found. Skipping...
# Processing Record 18 of the Set 9 | rungata
# Processing Record 19 of the Set 9 | salinas
# Processing Record 20 of the Set 9 | lakselv
# Processing Record 21 of the Set 9 | port keats
# Processing Record 22 of the Set 9 | oktyabrskiy
# Processing Record 23 of the Set 9 | leeton
# Processing Record 24 of the Set 9 | khovu-aksy
# Processing Record 25 of the Set 9 | kavieng
# Processing Record 26 of the Set 9 | wanaka
# Processing Record 27 of the Set 9 | lavrentiya
# Processing Record 28 of the Set 9 | west bay
# Processing Record 29 of the Set 9 | faya
# Processing Record 30 of the Set 9 | praia da vitoria
# Processing Record 31 of the Set 9 | barcelos
# Processing Record 32 of the Set 9 | ub
# City not found. Skipping...
# Processing Record 33 of the Set 9 | jizan
# Processing Record 34 of the Set 9 | capim grosso
# Processing Record 35 of the Set 9 | runkel
# Processing Record 36 of the Set 9 | freetown
# Processing Record 37 of the Set 9 | davila
# Processing Record 38 of the Set 9 | normandin
# Processing Record 39 of the Set 9 | moose factory
# Processing Record 40 of the Set 9 | colon
# Processing Record 41 of the Set 9 | ixtapa
# Processing Record 42 of the Set 9 | gulshat
# Processing Record 43 of the Set 9 | vardo
# Processing Record 44 of the Set 9 | te anau
# Processing Record 45 of the Set 9 | chipinge
# Processing Record 46 of the Set 9 | siukh
# Processing Record 47 of the Set 9 | temaraia
# Processing Record 48 of the Set 9 | buala
# Processing Record 49 of the Set 9 | kotka
# Processing Record 50 of the Set 9 | salalah
# Processing Record 1 of the Set 10 | dracena
# Processing Record 2 of the Set 10 | dingle
# Processing Record 3 of the Set 10 | srednekolymsk
# Processing Record 4 of the Set 10 | malakisi
# Processing Record 5 of the Set 10 | gat
# Processing Record 6 of the Set 10 | san carlos sija
# Processing Record 7 of the Set 10 | plouzane
# Processing Record 8 of the Set 10 | turtkul
# Processing Record 9 of the Set 10 | frontera
# Processing Record 10 of the Set 10 | saldanha
# Processing Record 11 of the Set 10 | biggar
# Processing Record 12 of the Set 10 | olafsvik
# Processing Record 13 of the Set 10 | norsup
# Processing Record 14 of the Set 10 | tarakan
# Processing Record 15 of the Set 10 | opuwo
# Processing Record 16 of the Set 10 | talara
# Processing Record 17 of the Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of the Set 10 | halalo
# City not found. Skipping...
# Processing Record 19 of the Set 10 | doctor pedro p. pena
# Processing Record 20 of the Set 10 | halifax
# Processing Record 21 of the Set 10 | piskivka
# Processing Record 22 of the Set 10 | sheltozero
# Processing Record 23 of the Set 10 | fairmont
# Processing Record 24 of the Set 10 | puerto leguizamo
# Processing Record 25 of the Set 10 | oranjemund
# Processing Record 26 of the Set 10 | morant bay
# Processing Record 27 of the Set 10 | ardatov
# Processing Record 28 of the Set 10 | urumqi
# Processing Record 29 of the Set 10 | namibe
# Processing Record 30 of the Set 10 | leua
# Processing Record 31 of the Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 32 of the Set 10 | camopi
# Processing Record 33 of the Set 10 | kloulklubed
# City not found. Skipping...
# Processing Record 34 of the Set 10 | san matias
# Processing Record 35 of the Set 10 | san andres
# Processing Record 36 of the Set 10 | ust-kamchatsk
# Processing Record 37 of the Set 10 | jacareacanga
# Processing Record 38 of the Set 10 | margate
# Processing Record 39 of the Set 10 | killybegs
# Processing Record 40 of the Set 10 | viligili
# Processing Record 41 of the Set 10 | igrim
# Processing Record 42 of the Set 10 | la trinidad
# Processing Record 43 of the Set 10 | tura
# Processing Record 44 of the Set 10 | andenes
# Processing Record 45 of the Set 10 | laguna
# Processing Record 46 of the Set 10 | sompeta
# Processing Record 47 of the Set 10 | mohiuddinagar
# Processing Record 48 of the Set 10 | belaya gora
# Processing Record 49 of the Set 10 | smirnykh
# Processing Record 50 of the Set 10 | yanan
# Processing Record 1 of the Set 11 | copiapo
# Processing Record 2 of the Set 11 | salinopolis
# Processing Record 3 of the Set 11 | sobolevo
# Processing Record 4 of the Set 11 | aranda de duero
# Processing Record 5 of the Set 11 | bathsheba
# Processing Record 6 of the Set 11 | saint-georges
# Processing Record 7 of the Set 11 | ponta delgada
# Processing Record 8 of the Set 11 | jaque
# Processing Record 9 of the Set 11 | onverwacht
# Processing Record 10 of the Set 11 | almaznyy
# Processing Record 11 of the Set 11 | alyangula
# Processing Record 12 of the Set 11 | ranfurly
# Processing Record 13 of the Set 11 | zhanatas
# Processing Record 14 of the Set 11 | loa janan
# Processing Record 15 of the Set 11 | rockland
# Processing Record 16 of the Set 11 | brokopondo
# Processing Record 17 of the Set 11 | araouane
# Processing Record 18 of the Set 11 | kamen-rybolov
# Processing Record 19 of the Set 11 | phalaborwa
# Processing Record 20 of the Set 11 | vyazemskiy
# Processing Record 21 of the Set 11 | gumdag
# Processing Record 22 of the Set 11 | bogalusa
# Processing Record 23 of the Set 11 | cayenne
# Processing Record 24 of the Set 11 | khambhat
# Processing Record 25 of the Set 11 | meulaboh
# Processing Record 26 of the Set 11 | san quintin
# Processing Record 27 of the Set 11 | muros
# Processing Record 28 of the Set 11 | belem de sao francisco
# Processing Record 29 of the Set 11 | hualmay
# Processing Record 30 of the Set 11 | umm lajj
# Processing Record 31 of the Set 11 | mansa
# Processing Record 32 of the Set 11 | badarpur
# Processing Record 33 of the Set 11 | utiroa
# Processing Record 34 of the Set 11 | kattivakkam
# Processing Record 35 of the Set 11 | nouakchott
# Processing Record 36 of the Set 11 | taoudenni
# Processing Record 37 of the Set 11 | surman
# Processing Record 38 of the Set 11 | menongue
# Processing Record 39 of the Set 11 | wanning
# Processing Record 40 of the Set 11 | farnborough
# Processing Record 41 of the Set 11 | dombarovskiy
# Processing Record 42 of the Set 11 | yar-sale
# Processing Record 43 of the Set 11 | ahipara
# Processing Record 44 of the Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of the Set 11 | boffa
# Processing Record 46 of the Set 11 | asau
# Processing Record 47 of the Set 11 | manitowoc
# Processing Record 48 of the Set 11 | young
# Processing Record 49 of the Set 11 | zhanakorgan
# Processing Record 50 of the Set 11 | astipalaia
# City not found. Skipping...
# Processing Record 1 of the Set 12 | hanzhong
# Processing Record 2 of the Set 12 | new ulm
# Processing Record 3 of the Set 12 | yining
# Processing Record 4 of the Set 12 | mahanoro
# Processing Record 5 of the Set 12 | ketchikan
# Processing Record 6 of the Set 12 | kaihua
# Processing Record 7 of the Set 12 | aqtobe
# Processing Record 8 of the Set 12 | santa isabel do rio negro
# Processing Record 9 of the Set 12 | angoche
# Processing Record 10 of the Set 12 | turukhansk
# Processing Record 11 of the Set 12 | serenje
# Processing Record 12 of the Set 12 | fortuna
# Processing Record 13 of the Set 12 | krasnoselkup
# Processing Record 14 of the Set 12 | manyana
# Processing Record 15 of the Set 12 | evensk
# Processing Record 16 of the Set 12 | slave lake
# Processing Record 17 of the Set 12 | erdenet
# Processing Record 18 of the Set 12 | pochutla
# Processing Record 19 of the Set 12 | lenoir
# Processing Record 20 of the Set 12 | broken hill
# Processing Record 21 of the Set 12 | morondava
# Processing Record 22 of the Set 12 | kampong thum
# Processing Record 23 of the Set 12 | sinop
# City not found. Skipping...
# Processing Record 24 of the Set 12 | ukiah
# Processing Record 25 of the Set 12 | puerto del rosario
# Processing Record 26 of the Set 12 | haian
# Processing Record 27 of the Set 12 | taylors
# Processing Record 28 of the Set 12 | nyagan
# Processing Record 29 of the Set 12 | san policarpo
# Processing Record 30 of the Set 12 | rorvik
# Processing Record 31 of the Set 12 | huntsville
# Processing Record 32 of the Set 12 | mattru
# Processing Record 33 of the Set 12 | gazli
# Processing Record 34 of the Set 12 | kiruna
# Processing Record 35 of the Set 12 | ust-ordynskiy
# Processing Record 36 of the Set 12 | kulu
# City not found. Skipping...
# Processing Record 37 of the Set 12 | karsava
# Processing Record 38 of the Set 12 | valpoi
# Processing Record 39 of the Set 12 | lithakia
# City not found. Skipping...
# Processing Record 40 of the Set 12 | ossora
# Processing Record 41 of the Set 12 | qui nhon
# Processing Record 42 of the Set 12 | sibu
# City not found. Skipping...
# Processing Record 43 of the Set 12 | los llanos de aridane
# Processing Record 44 of the Set 12 | kefamenanu
# Processing Record 45 of the Set 12 | karimganj
# Processing Record 46 of the Set 12 | miraflores
# Processing Record 47 of the Set 12 | sindi
# Processing Record 48 of the Set 12 | alice springs
# Processing Record 49 of the Set 12 | loandjili
# Processing Record 50 of the Set 12 | ormara
# Processing Record 1 of the Set 13 | tazovskiy
# Processing Record 2 of the Set 13 | constitucion
# Processing Record 3 of the Set 13 | tecolutla
# Processing Record 4 of the Set 13 | barawe
# Processing Record 5 of the Set 13 | folkestone
# Processing Record 6 of the Set 13 | port hedland
# Processing Record 7 of the Set 13 | abbotsford
# Processing Record 8 of the Set 13 | obidos
# Processing Record 9 of the Set 13 | nanyuki
# Processing Record 10 of the Set 13 | sterling
# Processing Record 11 of the Set 13 | winslow
# Processing Record 12 of the Set 13 | saint anthony
# Processing Record 13 of the Set 13 | susangerd
# Processing Record 14 of the Set 13 | zanjan
# Processing Record 15 of the Set 13 | longyearbyen
# Processing Record 16 of the Set 13 | kolondieba
# Processing Record 17 of the Set 13 | necochea
# Processing Record 18 of the Set 13 | talakan
# Processing Record 19 of the Set 13 | yima
# Processing Record 20 of the Set 13 | aklavik
# Processing Record 21 of the Set 13 | roald
# Processing Record 22 of the Set 13 | aknada
# Processing Record 23 of the Set 13 | great yarmouth
# Processing Record 24 of the Set 13 | kandrian
# Processing Record 25 of the Set 13 | kenora
# Processing Record 26 of the Set 13 | abonnema
# Processing Record 27 of the Set 13 | markova
# Processing Record 28 of the Set 13 | khangarh
# Processing Record 29 of the Set 13 | hobyo
# Processing Record 30 of the Set 13 | bara
# Processing Record 31 of the Set 13 | kamenskoye
# Processing Record 32 of the Set 13 | bar harbor
# Processing Record 33 of the Set 13 | riverton
# Processing Record 34 of the Set 13 | erenhot
# Processing Record 35 of the Set 13 | cumana
# Processing Record 36 of the Set 13 | silver city
# Processing Record 37 of the Set 13 | ludwigsfelde
# Processing Record 38 of the Set 13 | nalut
# Processing Record 39 of the Set 13 | kwekwe
# Processing Record 40 of the Set 13 | camana
# Processing Record 41 of the Set 13 | aljezur
# Processing Record 42 of the Set 13 | kytlym
# Processing Record 43 of the Set 13 | taltal
# Processing Record 44 of the Set 13 | ambon
# Processing Record 45 of the Set 13 | ostrovnoy
# Processing Record 46 of the Set 13 | amot
# Processing Record 47 of the Set 13 | kibala
# Processing Record 48 of the Set 13 | westlock
# Processing Record 49 of the Set 13 | piatra
# Processing Record 50 of the Set 13 | ponta do sol
# Processing Record 1 of the Set 14 | puerto escondido
# Processing Record 2 of the Set 14 | villa del rosario
# Processing Record 3 of the Set 14 | padang
# Processing Record 4 of the Set 14 | ochakiv
# Processing Record 5 of the Set 14 | woodward
# Processing Record 6 of the Set 14 | ribeira grande
# Processing Record 7 of the Set 14 | novomyrhorod
# Processing Record 8 of the Set 14 | burica
# Processing Record 9 of the Set 14 | pithora
# Processing Record 10 of the Set 14 | shingu
# Processing Record 11 of the Set 14 | kingaroy
# Processing Record 12 of the Set 14 | paragominas
# Processing Record 13 of the Set 14 | manoel urbano
# Processing Record 14 of the Set 14 | capitan bado
# Processing Record 15 of the Set 14 | belz
# Processing Record 16 of the Set 14 | soavinandriana
# Processing Record 17 of the Set 14 | san patricio
# Processing Record 18 of the Set 14 | santa cruz
# Processing Record 19 of the Set 14 | bonthe
# Processing Record 20 of the Set 14 | sarankhola
# Processing Record 21 of the Set 14 | kinkala
# Processing Record 22 of the Set 14 | guaimaro
# Processing Record 23 of the Set 14 | benguela
# Processing Record 24 of the Set 14 | borogontsy
# Processing Record 25 of the Set 14 | komsomolskiy
# Processing Record 26 of the Set 14 | karratha
# Processing Record 27 of the Set 14 | cairns
# Processing Record 28 of the Set 14 | lithgow
# Processing Record 29 of the Set 14 | kyra
# Processing Record 30 of the Set 14 | khormuj
# Processing Record 31 of the Set 14 | teguldet
# Processing Record 32 of the Set 14 | bambanglipuro
# Processing Record 33 of the Set 14 | mabaruma
# Processing Record 34 of the Set 14 | walvis bay
# Processing Record 35 of the Set 14 | pangnirtung
# Processing Record 36 of the Set 14 | matara
# City not found. Skipping...
# Processing Record 37 of the Set 14 | kyrksaeterora
# Processing Record 38 of the Set 14 | nizwa
# Processing Record 39 of the Set 14 | kaele
# Processing Record 40 of the Set 14 | jinji
# Processing Record 41 of the Set 14 | guymon
# Processing Record 42 of the Set 14 | monticello
# Processing Record 43 of the Set 14 | presidencia roque saenz pena
# Processing Record 44 of the Set 14 | dubbo
# Processing Record 45 of the Set 14 | port blair
# Processing Record 46 of the Set 14 | taquarituba
# Processing Record 47 of the Set 14 | ljungby
# Processing Record 48 of the Set 14 | plettenberg bay
# Processing Record 49 of the Set 14 | chulman
# Processing Record 50 of the Set 14 | bogotol
# Processing Record 1 of the Set 15 | trincomalee
# City not found. Skipping...
# Processing Record 2 of the Set 15 | ust-kuyga
# Processing Record 3 of the Set 15 | edson
# Processing Record 4 of the Set 15 | banjar
# Processing Record 5 of the Set 15 | dillon
# Processing Record 6 of the Set 15 | beringovskiy
# Processing Record 7 of the Set 15 | gdov
# Processing Record 8 of the Set 15 | bilma
# Processing Record 9 of the Set 15 | ulladulla
# Processing Record 10 of the Set 15 | fraga
# Processing Record 11 of the Set 15 | batagay-alyta
# Processing Record 12 of the Set 15 | cefa
# Processing Record 13 of the Set 15 | swellendam
# Processing Record 14 of the Set 15 | kosh-agach
# Processing Record 15 of the Set 15 | colac
# Processing Record 16 of the Set 15 | sur
# Processing Record 17 of the Set 15 | havoysund
# Processing Record 18 of the Set 15 | ugoofaaru
# Processing Record 19 of the Set 15 | paita
# Processing Record 20 of the Set 15 | ballina
# Processing Record 21 of the Set 15 | trat
# Processing Record 22 of the Set 15 | kununurra
# Processing Record 23 of the Set 15 | livingstonia
# Processing Record 24 of the Set 15 | tuggurt
# Processing Record 25 of the Set 15 | hervey bay
# Processing Record 26 of the Set 15 | ca mau
# Processing Record 27 of the Set 15 | zelenoborsk
# Processing Record 28 of the Set 15 | pavlogradka
# Processing Record 29 of the Set 15 | chino valley
# Processing Record 30 of the Set 15 | hambantota
# City not found. Skipping...
# Processing Record 31 of the Set 15 | aksarka
# Processing Record 32 of the Set 15 | ewa beach
# Processing Record 33 of the Set 15 | wajima
# Processing Record 34 of the Set 15 | sinnamary
# Processing Record 35 of the Set 15 | kota kinabalu
# Processing Record 36 of the Set 15 | hun
# Processing Record 37 of the Set 15 | putina
# Processing Record 38 of the Set 15 | ryotsu
# Processing Record 39 of the Set 15 | kankon
# Processing Record 40 of the Set 15 | vyartsilya
# Processing Record 41 of the Set 15 | khandyga
# Processing Record 42 of the Set 15 | el badari
# Processing Record 43 of the Set 15 | druzhba
# Processing Record 44 of the Set 15 | beboto
# Processing Record 45 of the Set 15 | luzhou
# Processing Record 46 of the Set 15 | porto novo
# Processing Record 47 of the Set 15 | lushunkou
# Processing Record 48 of the Set 15 | kuche
# Processing Record 49 of the Set 15 | vuktyl
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 720

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Adrar      MR  20.5022  -10.0711    101.73         9          60
# 1  Kaitangata      NZ -46.2817  169.8464     46.04        85          84
# 2        Gizo      SB  -8.1030  156.8419     81.59        77          40
# 3     Sakakah      SA  29.9697   40.2064     91.54        16          22
# 4  Parfenyevo      RU  58.4840   43.4088     58.48        80          99
#
#    Wind Speed Current Description
# 0        9.28       broken clouds
# 1        5.68       broken clouds
# 2        6.22    scattered clouds
# 3        3.98          few clouds
# 4        2.28     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
